# %%
from configs import paths
import pandas as pd
import os

# %%
path = os.path.join(paths.CONFIG["paths"]["results"], "Results_df.csv")
df = pd.read_csv(path)
df.head()
# Out:
#    run_id  seed  best_epoch  best_val_loss   roc_auc  average_precision  \
# 0       1     1           1       0.704611  0.625606           0.619945
# 1       2     2           1       0.705897  0.586159           0.589075
# 2       3     3           1       0.727093  0.611626           0.602503
# 3       4     4           1       0.707833  0.606920           0.609068
#
#    n_epochs  final_train_loss  final_val_loss model_class optimizer_class
# 0        31          0.224196        1.873299         GCN            Adam
# 1        31          0.162727        2.173676         GCN            Adam
# 2        31          0.203648        2.384543         GCN            Adam
# 3        31          0.217595        1.895657         GCN            Adam
