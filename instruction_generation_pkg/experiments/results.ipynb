# %%
from configs import paths
import pandas as pd
import os

# %%
path = os.path.join(paths.CONFIG["paths"]["results"], "Results_df.csv")
df = pd.read_csv(path)
df.head()
# Out:
#    run_id  seed  best_epoch  best_val_loss   roc_auc  average_precision  \
# 0       1     1          25       0.951745  0.566406           0.584184
# 1       2     2          26       1.075356  0.550781           0.589988
# 2       3     3          25       0.953781  0.519531           0.583774
# 3       4     4           2       1.183442  0.621094           0.634091
#
#    n_epochs  final_train_loss  final_val_loss model_class optimizer_class
# 0        55          0.043885        1.080651         GCN            Adam
# 1        56          0.034110        1.155338         GCN            Adam
# 2        55          0.032152        1.126306         GCN            Adam
# 3        32          0.089773        1.315048         GCN            Adam
