# %%
from configs import paths
import pandas as pd
import os

# %%
path = os.path.join(paths.CONFIG["paths"]["results"], "Results_df.csv")
df = pd.read_csv(path)
df.head()
# Out:
#    run_id  seed  best_epoch  best_val_loss   roc_auc  average_precision  \
# 0       1     1           7       0.601565  0.640625           0.689107
# 1       2     2           7       0.586452  0.652344           0.699934
# 2       3     3           6       0.631719  0.652344           0.716194
# 3       4     4           6       0.629831  0.636719           0.697085
#
#    n_epochs  final_train_loss  final_val_loss model_class optimizer_class
# 0        37          0.008838        1.771589         GCN            Adam
# 1        37          0.009260        1.867064         GCN            Adam
# 2        36          0.007456        1.985721         GCN            Adam
# 3        36          0.009517        2.307013         GCN            Adam
