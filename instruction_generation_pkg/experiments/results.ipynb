# %%
from configs import paths
import pandas as pd
import os

# %%
path = os.path.join(paths.CONFIG["paths"]["results"], "Results_df.csv")
df = pd.read_csv(path)
df.head()
# Out:
#    run_id  seed  best_epoch  best_val_loss   roc_auc  average_precision  \
# 0       1     1           7       0.601554  0.730469           0.772796
# 1       2     2           7       0.586560  0.718750           0.749223
# 2       3     3           6       0.631706  0.753906           0.794849
# 3       4     4           6       0.629843  0.742188           0.789266
#
#    n_epochs  final_train_loss  final_val_loss model_class optimizer_class
# 0        37          0.009329        1.719437         GCN            Adam
# 1        37          0.008119        1.907395         GCN            Adam
# 2        36          0.007130        1.982273         GCN            Adam
# 3        36          0.008082        2.142998         GCN            Adam
