# %%
from configs import paths
import pandas as pd
import os

# %%
path = os.path.join(paths.CONFIG["paths"]["results"], "Results_df.csv")
df = pd.read_csv(path)
df.head()
# Out:
#    run_id  seed  best_epoch  best_val_loss   roc_auc  average_precision  \
# 0       1     1           9       1.337218  0.921875           0.927933
# 1       2     2          10       1.488477  0.906250           0.904034
# 2       3     3          15       2.486747  0.875000           0.800943
# 3       4     4          11       3.188758  0.902344           0.878590
#
#    n_epochs  final_train_loss  final_val_loss model_class optimizer_class
# 0        39         15.808360       25.956564         GCN            Adam
# 1        40          2.206198        9.221588         GCN            Adam
# 2        45          6.510894       11.686696         GCN            Adam
# 3        41          2.431059        7.938570         GCN            Adam
